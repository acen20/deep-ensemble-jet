# %% [markdown]
# # **Ransomware Analysis using DEL with jet-like architecture**
#
# > Ahsen Nazir

# %%
# !wget -nv -O cnn1_4.pt https://github.com/acen20/deep-ensemble-jet/raw/master/models/cnn1_4.pt
# !wget -nv -O cnn2_5.pt https://github.com/acen20/deep-ensemble-jet/raw/master/models/cnn2_5.pt
# !wget -nv -O sparse_encoder.pt https://github.com/acen20/deep-ensemble-jet/raw/master/models/sparse_encoder.pt
# !wget -nv -O undercomplete_encoder.pt https://github.com/acen20/deep-ensemble-jet/raw/master/models/undercomplete_encoder.pt
# !wget -nv -O data.csv https://github.com/acen20/deep-ensemble-jet/raw/master/dataset/ClaMP_Integrated-5184.csv
# Out:
# 2022-01-08 07:01:30 URL:https://raw.githubusercontent.com/acen20/deep-ensemble-jet/master/models/cnn1_4.pt [17306/17306] -> "cnn1_4.pt" [1]
# 2022-01-08 07:01:31 URL:https://raw.githubusercontent.com/acen20/deep-ensemble-jet/master/models/cnn2_5.pt [19525/19525] -> "cnn2_5.pt" [1]
# 2022-01-08 07:01:31 URL:https://raw.githubusercontent.com/acen20/deep-ensemble-jet/master/models/sparse_encoder.pt [181393/181393] -> "sparse_encoder.pt" [1]
# 2022-01-08 07:01:31 URL:https://raw.githubusercontent.com/acen20/deep-ensemble-jet/master/models/undercomplete_encoder.pt [204021/204021] -> "undercomplete_encoder.pt" [1]
# 2022-01-08 07:01:32 URL:https://raw.githubusercontent.com/acen20/deep-ensemble-jet/master/dataset/ClaMP_Integrated-5184.csv [1283431/1283431] -> "data.csv" [1]

# %%
import torch
from torch import nn
from torchvision import transforms
from torch.utils.data import TensorDataset, DataLoader
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve
from matplotlib import pyplot
from sklearn.metrics import f1_score
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.model_selection import cross_val_score
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.preprocessing import MinMaxScaler

# %%
from warnings import simplefilter
from sklearn.exceptions import ConvergenceWarning
simplefilter("ignore", category=ConvergenceWarning)

# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# Loading Dataset
# Dataset link: https://data.mendeley.com/datasets/xvyv59vwvz/1
# Dataset is present in the current directory containing the code file.
df=pd.read_csv('data.csv')

# %% [markdown]
# ## Preprocessing

# %%
df.head()
# Out:
#    e_cblp  e_cp  e_cparhdr  e_maxalloc  ...  filesize    E_file  fileinfo  class
# 0     144     3          4       65535  ...   1181520  6.627552         1      0
# 1     144     3          4       65535  ...      7680  5.318221         0      0
# 2     144     3          4       65535  ...     57872  6.507758         1      0
# 3     144     3          4       65535  ...     95616  4.575092         1      0
# 4     144     3          4       65535  ...     48128  5.545531         1      0
#
# [5 rows x 70 columns]

# %%
# Replacing Null values with 0. ML classifer cannot learn on Null values
df.fillna(0, inplace=True)

# %%
# Peak on dataset
df.head()
# Out:
#    e_cblp  e_cp  e_cparhdr  e_maxalloc  ...  filesize    E_file  fileinfo  class
# 0     144     3          4       65535  ...   1181520  6.627552         1      0
# 1     144     3          4       65535  ...      7680  5.318221         0      0
# 2     144     3          4       65535  ...     57872  6.507758         1      0
# 3     144     3          4       65535  ...     95616  4.575092         1      0
# 4     144     3          4       65535  ...     48128  5.545531         1      0
#
# [5 rows x 70 columns]

# %%
# Droping these columns due to their insignificance
df=df.drop(['NumberOfSections','CreationYear','e_cblp','e_cp','e_cparhdr','e_maxalloc'], axis=1)

# %%
df.shape
# Out:
# (5210, 64)

# %%
# Peak on the dataset
df.head()
# Out:
#    e_sp  e_lfanew  FH_char0  FH_char1  ...  filesize    E_file  fileinfo  class
# 0   184       256         0         1  ...   1181520  6.627552         1      0
# 1   184       184         0         1  ...      7680  5.318221         0      0
# 2   184       272         0         1  ...     57872  6.507758         1      0
# 3   184       184         0         1  ...     95616  4.575092         1      0
# 4   184       224         0         1  ...     48128  5.545531         1      0
#
# [5 rows x 64 columns]

# %%
ransomware,goodware = df['class'].value_counts()

# %% [markdown]
# **Ransomware vs Goodware**

# %%
print(f'Ransomware: {ransomware}')
print(f'Goodware: {goodware}')
# Out:
# Ransomware: 2722
# Goodware: 2488

# %%
# Encodings Labels so that they are compatible with machine leanring classifiers
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in df:
    if df[i].dtype=='object':
        df[i] = le.fit_transform(df[i])
    else:
        continue
X = df.drop(['class'],axis=1)
y = df['class']

# %%
# Now check the features for the feature column "Packer_type". They are converted fr
df.head()
# Out:
#    e_sp  e_lfanew  FH_char0  FH_char1  ...  filesize    E_file  fileinfo  class
# 0   184       256         0         1  ...   1181520  6.627552         1      0
# 1   184       184         0         1  ...      7680  5.318221         0      0
# 2   184       272         0         1  ...     57872  6.507758         1      0
# 3   184       184         0         1  ...     95616  4.575092         1      0
# 4   184       224         0         1  ...     48128  5.545531         1      0
#
# [5 rows x 64 columns]

# %%
# Scaling data. Default scaling is to scale the data to unit variance (or equivalent
mms = MinMaxScaler()
X = mms.fit_transform(X)
X = torch.tensor(X, dtype=torch.float)

# %% [markdown]
# ## CNN Wing 1

# %%
class CNN1(nn.Module):
  def __init__(self):
    super(CNN1, self).__init__()
    self.cnn = nn.Sequential(
        nn.Conv1d(1,3,kernel_size = (1,4), stride=1),
        nn.ReLU(),
        nn.BatchNorm2d(3),
        nn.Conv1d(3,3,kernel_size = (1,4), stride=1),
        nn.ReLU(),
        nn.BatchNorm2d(3),
        nn.Conv1d(3,3,kernel_size = (1,4), stride=1),
        nn.ReLU(),
        nn.BatchNorm2d(3),
        nn.Flatten(),
        nn.Linear(162, 15),
        nn.ReLU()
    )

    self.clf = nn.Sequential(
        nn.Linear(15,1),
        nn.Sigmoid()
    )

  def forward(self, x):
    features = self.cnn(x)
    return self.clf(features)

  def transform(self, x):
    return self.cnn(x)

# %%
cnn1 = CNN1()
cnn1.load_state_dict(torch.load('cnn1_4.pt'))
cnn1.eval()
with torch.no_grad():
  f1 = cnn1.transform(X.view(-1,1,1,63))

# %% [markdown]
# ## CNN Wing 2

# %%
class CNN2(nn.Module):
  final_dims = 15
  def __init__(self):
    super(CNN2, self).__init__()
    self.cnn = nn.Sequential(
        nn.Conv1d(1,3,kernel_size = (1,3), stride=1),
        nn.ReLU(),
        nn.BatchNorm2d(3),
        nn.Conv1d(3,3,kernel_size = (1,3), stride=1),
        nn.ReLU(),
        nn.BatchNorm2d(3),
        nn.Conv1d(3,3,kernel_size = (1,3), stride=1),
        nn.ReLU(),
        nn.BatchNorm2d(3),
        nn.Conv1d(3,3,kernel_size = (1,3), stride=1),
        nn.ReLU(),
        nn.BatchNorm2d(3),
        nn.Flatten(),
        nn.Linear(165, self.final_dims),
        nn.ReLU()
    )

    self.clf = nn.Sequential(
        nn.Linear(15,1),
        nn.Sigmoid()
    )

  def forward(self, x):
    features = self.cnn(x)
    return self.clf(features)

  def transform(self, x):
    return self.cnn(x)

# %%
cnn2 = CNN2()
cnn2.load_state_dict(torch.load('cnn2_5.pt'))
cnn2.eval()
with torch.no_grad():
  f2 = cnn2.transform(X.view(-1,1,1,63))

# %% [markdown]
# ## Sparse AE Tail

# %%
features = 15
current_dims = len(df.columns)-1

# %%
class SparseEncoder(nn.Module):
  def __init__(self):
    super().__init__()
    self.encoder = nn.Sequential(
        nn.Linear(current_dims, current_dims*2),
        nn.BatchNorm1d(current_dims*2),
        nn.LeakyReLU(),
        nn.Dropout(0.1),
        nn.Linear(current_dims*2, current_dims*2),
        nn.BatchNorm1d(current_dims*2),
        nn.LeakyReLU(),
        nn.Dropout(0.1),
        nn.Linear(current_dims*2, current_dims*2),
        nn.BatchNorm1d(current_dims*2),
        nn.LeakyReLU(),
        nn.Dropout(0.1),
        nn.Linear(current_dims*2, features),
        nn.BatchNorm1d(features),
        nn.LeakyReLU(),
    )

  def forward(self, x):
    encoded = self.encoder(x)
    return encoded

# %%
sparse_ae = SparseEncoder()
sparse_ae.load_state_dict(torch.load('sparse_encoder.pt'))
sparse_ae.eval()
with torch.no_grad():
  f3 = sparse_ae(X)

# %%
f1.shape,f2.shape,f3.shape, X.shape
# Out:
# (torch.Size([5210, 15]),
#  torch.Size([5210, 15]),
#  torch.Size([5210, 15]),
#  torch.Size([5210, 63]))

# %% [markdown]
# New dimensions after concatenating **F1, F2, F3 and Input**

# %%
new_features = torch.cat((f1,f2,f3,X),dim = 1)
print(new_features.shape)
# Out:
# torch.Size([5210, 108])

# %% [markdown]
# ## NLPCA Body

# %%
encoded_dims = 15
current_dims = new_features.shape[1]

# %%
class Encoder(nn.Module):
  def __init__(self):
    super().__init__()
    self.encoder = nn.Sequential(
        nn.Linear(current_dims, current_dims*2),
        nn.BatchNorm1d(current_dims*2),
        nn.LeakyReLU(),
        nn.Linear(current_dims*2, current_dims),
        nn.BatchNorm1d(current_dims),
        nn.LeakyReLU(),
        nn.Linear(current_dims,encoded_dims),
    )

  def forward(self, x):
    encoded = self.encoder(x)
    return encoded

# %%
nlpca = Encoder()
nlpca.load_state_dict(torch.load('undercomplete_encoder.pt'))
nlpca.eval()
with torch.no_grad():
  X = nlpca(new_features)

# %%
y = torch.tensor(y, dtype=torch.float)

# %%
# Dividing data into training, testing and validation
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.05, random_state=1)

# %%
X_train.shape, y_train.shape
# Out:
# (torch.Size([3959, 15]), torch.Size([3959]))

# %%
pt_train = TensorDataset(X_train, y_train)
pt_train = DataLoader(pt_train, batch_size=64)

# %% [markdown]
# ## MLP Classifier on new feature space

# %%
class MLP(nn.Module):
  def __init__(self):
    super(MLP, self).__init__()
    self.model = nn.Sequential(
        nn.Linear(15, 128),
        nn.BatchNorm1d(128),
        nn.ReLU(),
        nn.Linear(128, 128),
        nn.BatchNorm1d(128),
        nn.ReLU(),
        nn.Linear(128, 128),
        nn.BatchNorm1d(128),
        nn.ReLU(),
        nn.Linear(128, 64),
        nn.BatchNorm1d(64),
        nn.ReLU(),
        nn.Linear(64, 20),
        nn.BatchNorm1d(20),
        nn.ReLU()
    )
    self.clf = nn.Sequential(
        nn.Linear(20, 1),
        nn.Sigmoid()
    )
  def forward(self, x):
      output = self.model(x)
      return self.clf(output)

# %%
mlp = MLP()
epochs = 150
lr = 1e-2
optimizer = torch.optim.SGD(mlp.parameters(), lr = lr)
criterion = nn.BCELoss()

# %%
losses = []
for epoch in range(epochs):
  for batch_idx, (x, target) in enumerate(pt_train):
    output = mlp(x)
    loss = criterion(output, target.view(-1,1))
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    if batch_idx == 0:
      print(
          f"Epoch [{epoch+1}/{epochs}] \ "
          f"Loss: {loss.item():.4f}"
      ) 
  losses.append(loss.item())
# Out:
# Epoch [1/150] \ Loss: 0.7112
# Epoch [2/150] \ Loss: 0.3068
# Epoch [3/150] \ Loss: 0.2109
# Epoch [4/150] \ Loss: 0.1560
# Epoch [5/150] \ Loss: 0.1212
# Epoch [6/150] \ Loss: 0.0982
# Epoch [7/150] \ Loss: 0.0820
# Epoch [8/150] \ Loss: 0.0701
# Epoch [9/150] \ Loss: 0.0612
# Epoch [10/150] \ Loss: 0.0542
# Epoch [11/150] \ Loss: 0.0489
# Epoch [12/150] \ Loss: 0.0442
# Epoch [13/150] \ Loss: 0.0403
# Epoch [14/150] \ Loss: 0.0375
# Epoch [15/150] \ Loss: 0.0347
# Epoch [16/150] \ Loss: 0.0325
# Epoch [17/150] \ Loss: 0.0305
# Epoch [18/150] \ Loss: 0.0288
# Epoch [19/150] \ Loss: 0.0270
# Epoch [20/150] \ Loss: 0.0252
# Epoch [21/150] \ Loss: 0.0240
# Epoch [22/150] \ Loss: 0.0228
# Epoch [23/150] \ Loss: 0.0222
# Epoch [24/150] \ Loss: 0.0206
# Epoch [25/150] \ Loss: 0.0195
# Epoch [26/150] \ Loss: 0.0184
# Epoch [27/150] \ Loss: 0.0177
# Epoch [28/150] \ Loss: 0.0166
# Epoch [29/150] \ Loss: 0.0156
# Epoch [30/150] \ Loss: 0.0151
# Epoch [31/150] \ Loss: 0.0143
# Epoch [32/150] \ Loss: 0.0136
# Epoch [33/150] \ Loss: 0.0134
# Epoch [34/150] \ Loss: 0.0124
# Epoch [35/150] \ Loss: 0.0122
# Epoch [36/150] \ Loss: 0.0116
# Epoch [37/150] \ Loss: 0.0111
# Epoch [38/150] \ Loss: 0.0105
# Epoch [39/150] \ Loss: 0.0103
# Epoch [40/150] \ Loss: 0.0096
# Epoch [41/150] \ Loss: 0.0096
# Epoch [42/150] \ Loss: 0.0095
# Epoch [43/150] \ Loss: 0.0087
# Epoch [44/150] \ Loss: 0.0081
# Epoch [45/150] \ Loss: 0.0081
# Epoch [46/150] \ Loss: 0.0078
# Epoch [47/150] \ Loss: 0.0077
# Epoch [48/150] \ Loss: 0.0072
# Epoch [49/150] \ Loss: 0.0070
# Epoch [50/150] \ Loss: 0.0067
# Epoch [51/150] \ Loss: 0.0064
# Epoch [52/150] \ Loss: 0.0067
# Epoch [53/150] \ Loss: 0.0058
# Epoch [54/150] \ Loss: 0.0058
# Epoch [55/150] \ Loss: 0.0062
# Epoch [56/150] \ Loss: 0.0061
# Epoch [57/150] \ Loss: 0.0054
# Epoch [58/150] \ Loss: 0.0053
# Epoch [59/150] \ Loss: 0.0055
# Epoch [60/150] \ Loss: 0.0053
# Epoch [61/150] \ Loss: 0.0047
# Epoch [62/150] \ Loss: 0.0047
# Epoch [63/150] \ Loss: 0.0048
# Epoch [64/150] \ Loss: 0.0054
# Epoch [65/150] \ Loss: 0.0047
# Epoch [66/150] \ Loss: 0.0047
# Epoch [67/150] \ Loss: 0.0042
# Epoch [68/150] \ Loss: 0.0042
# Epoch [69/150] \ Loss: 0.0043
# Epoch [70/150] \ Loss: 0.0041
# Epoch [71/150] \ Loss: 0.0042
# Epoch [72/150] \ Loss: 0.0040
# Epoch [73/150] \ Loss: 0.0036
# Epoch [74/150] \ Loss: 0.0038
# Epoch [75/150] \ Loss: 0.0033
# Epoch [76/150] \ Loss: 0.0036
# Epoch [77/150] \ Loss: 0.0036
# Epoch [78/150] \ Loss: 0.0032
# Epoch [79/150] \ Loss: 0.0036
# Epoch [80/150] \ Loss: 0.0032
# Epoch [81/150] \ Loss: 0.0031
# Epoch [82/150] \ Loss: 0.0029
# Epoch [83/150] \ Loss: 0.0029
# Epoch [84/150] \ Loss: 0.0027
# Epoch [85/150] \ Loss: 0.0028
# Epoch [86/150] \ Loss: 0.0028
# Epoch [87/150] \ Loss: 0.0026
# Epoch [88/150] \ Loss: 0.0024
# Epoch [89/150] \ Loss: 0.0024
# Epoch [90/150] \ Loss: 0.0027
# Epoch [91/150] \ Loss: 0.0024
# Epoch [92/150] \ Loss: 0.0024
# Epoch [93/150] \ Loss: 0.0024
# Epoch [94/150] \ Loss: 0.0022
# Epoch [95/150] \ Loss: 0.0023
# Epoch [96/150] \ Loss: 0.0022
# Epoch [97/150] \ Loss: 0.0025
# Epoch [98/150] \ Loss: 0.0021
# Epoch [99/150] \ Loss: 0.0021
# Epoch [100/150] \ Loss: 0.0020
# Epoch [101/150] \ Loss: 0.0021
# Epoch [102/150] \ Loss: 0.0019
# Epoch [103/150] \ Loss: 0.0018
# Epoch [104/150] \ Loss: 0.0019
# Epoch [105/150] \ Loss: 0.0019
# Epoch [106/150] \ Loss: 0.0018
# Epoch [107/150] \ Loss: 0.0019
# Epoch [108/150] \ Loss: 0.0018
# Epoch [109/150] \ Loss: 0.0030
# Epoch [110/150] \ Loss: 0.0017
# Epoch [111/150] \ Loss: 0.0017
# Epoch [112/150] \ Loss: 0.0018
# Epoch [113/150] \ Loss: 0.0017
# Epoch [114/150] \ Loss: 0.0017
# Epoch [115/150] \ Loss: 0.0016
# Epoch [116/150] \ Loss: 0.0016
# Epoch [117/150] \ Loss: 0.0016
# Epoch [118/150] \ Loss: 0.0016
# Epoch [119/150] \ Loss: 0.0016
# Epoch [120/150] \ Loss: 0.0015
# Epoch [121/150] \ Loss: 0.0015
# Epoch [122/150] \ Loss: 0.0015
# Epoch [123/150] \ Loss: 0.0014
# Epoch [124/150] \ Loss: 0.0016
# Epoch [125/150] \ Loss: 0.0014
# Epoch [126/150] \ Loss: 0.0015
# Epoch [127/150] \ Loss: 0.0014
# Epoch [128/150] \ Loss: 0.0014
# Epoch [129/150] \ Loss: 0.0014
# Epoch [130/150] \ Loss: 0.0014
# Epoch [131/150] \ Loss: 0.0013
# Epoch [132/150] \ Loss: 0.0013
# Epoch [133/150] \ Loss: 0.0013
# Epoch [134/150] \ Loss: 0.0013
# Epoch [135/150] \ Loss: 0.0012
# Epoch [136/150] \ Loss: 0.0012
# Epoch [137/150] \ Loss: 0.0012
# Epoch [138/150] \ Loss: 0.0012
# Epoch [139/150] \ Loss: 0.0012
# Epoch [140/150] \ Loss: 0.0012
# Epoch [141/150] \ Loss: 0.0012
# Epoch [142/150] \ Loss: 0.0012
# Epoch [143/150] \ Loss: 0.0012
# Epoch [144/150] \ Loss: 0.0012
# Epoch [145/150] \ Loss: 0.0011
# Epoch [146/150] \ Loss: 0.0011
# Epoch [147/150] \ Loss: 0.0011
# Epoch [148/150] \ Loss: 0.0011
# Epoch [149/150] \ Loss: 0.0011
# Epoch [150/150] \ Loss: 0.0011

# %%
plt.plot(losses)
plt.xlabel(f"epochs({epochs})")
plt.ylabel(f"loss")
_ = plt.legend(['Loss'])

# %%
_ = mlp.eval()

# %%
with torch.no_grad():
  lr_probs_1 = mlp(X_test).squeeze()
  ml_pred = lr_probs_1.round()

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, ml_pred)
tn=cm[0][0] #tn
fn=cm[0][1] #fn
fp=cm[1][0] #fp
tp=cm[1][1] #tp
acc= (tp+tn)/(tp+tn+fn+fp)
epsilon = 1e-7 # is used so that to avoid divide by zero error
precision = tp / (tp + fp + epsilon)
recall = tp / (tp + fn + epsilon)
sensitivity,specificity = tp/(tp+fn),tn/(tn+fp)
print("Test accuracy is:"+str(format(acc,'.4f')))
print("Precision: "+str(format(precision,'.4f'))+" Recall: "+str(format(recall,'.4f')))
# Out:
# Test accuracy is:0.9683
# Precision: 0.9734 Recall: 0.9642

# %%
from sklearn.metrics import auc
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
lr_precision, lr_recall, _ = precision_recall_curve(y_test, lr_probs_1)
lr_f1, lr_auc = f1_score(y_test, ml_pred), auc(lr_recall, lr_precision)
no_skill = len(y_test[y_test==1]) / len(y_test)
acc = accuracy_score(y_test, ml_pred)
plt.plot([0, 1], [no_skill, no_skill], linestyle='--', label='No Skill', c = "blue")
plt.plot(lr_recall, lr_precision, marker='.', label='Logistic', c = "orange")
# axis labels
plt.xlabel('Recall')
plt.ylabel('Precision')
# show the legend
plt.legend()
# show the plot
plt.show()
print("F1:",lr_f1)
print("AUC:",lr_auc)
print("Accuracy",acc)
disp = ConfusionMatrixDisplay(confusion_matrix = cm)
_ = disp.plot(cmap="copper", colorbar = False)
# Out:
# F1: 0.9687795648060549
# AUC: 0.9947737172880176
# Accuracy 0.9683301343570058

# %%
torch.save(mlp.state_dict(), 'mlp.pt')
