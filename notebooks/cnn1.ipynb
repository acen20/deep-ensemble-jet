# %%
import torch
from torch import nn
from torchvision import transforms
from torch.utils.data import TensorDataset, DataLoader
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve
from matplotlib import pyplot
from sklearn.metrics import f1_score
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.model_selection import cross_val_score
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.preprocessing import MinMaxScaler

# %%
from warnings import simplefilter
from sklearn.exceptions import ConvergenceWarning
simplefilter("ignore", category=ConvergenceWarning)

# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# Loading Dataset
# Dataset link: https://data.mendeley.com/datasets/xvyv59vwvz/1
# Dataset is present in the current directory containing the code file.
df=pd.read_csv('../dataset/data.csv')

# %% [markdown]
# ## Preprocessing

# %%
df.head()
# Out:
#    e_cblp  e_cp  e_cparhdr  e_maxalloc  ...  filesize    E_file  fileinfo  class
# 0     144     3          4       65535  ...   1181520  6.627552         1      0
# 1     144     3          4       65535  ...      7680  5.318221         0      0
# 2     144     3          4       65535  ...     57872  6.507758         1      0
# 3     144     3          4       65535  ...     95616  4.575092         1      0
# 4     144     3          4       65535  ...     48128  5.545531         1      0
#
# [5 rows x 70 columns]

# %%
# Replacing Null values with 0. ML classifer cannot learn on Null values
df.fillna(0, inplace=True)

# %%
# Peak on dataset
df.head()
# Out:
#    e_cblp  e_cp  e_cparhdr  e_maxalloc  ...  filesize    E_file  fileinfo  class
# 0     144     3          4       65535  ...   1181520  6.627552         1      0
# 1     144     3          4       65535  ...      7680  5.318221         0      0
# 2     144     3          4       65535  ...     57872  6.507758         1      0
# 3     144     3          4       65535  ...     95616  4.575092         1      0
# 4     144     3          4       65535  ...     48128  5.545531         1      0
#
# [5 rows x 70 columns]

# %%
# Droping these columns due to their insignificance
df=df.drop(['NumberOfSections','CreationYear','e_cblp','e_cp','e_cparhdr','e_maxalloc'], axis=1)

# %%
df.shape
# Out:
# (5210, 64)

# %%
# Peak on the dataset
df.head()
# Out:
#    e_sp  e_lfanew  FH_char0  FH_char1  ...  filesize    E_file  fileinfo  class
# 0   184       256         0         1  ...   1181520  6.627552         1      0
# 1   184       184         0         1  ...      7680  5.318221         0      0
# 2   184       272         0         1  ...     57872  6.507758         1      0
# 3   184       184         0         1  ...     95616  4.575092         1      0
# 4   184       224         0         1  ...     48128  5.545531         1      0
#
# [5 rows x 64 columns]

# %%
yes,no = df['class'].value_counts()

# %%
print(yes,no)
# Out:
# 2722 2488

# %%
#No class has less instances

# %%
# Encodings Labels so that they are compatible with machine leanring classifiers
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in df:
    if df[i].dtype=='object':
        df[i] = le.fit_transform(df[i])
    else:
        continue
X = df.drop(['class'],axis=1)
y = df['class']

# %%
# Now check the features for the feature column "Packer_type". They are converted fr
df.head()
# Out:
#    e_sp  e_lfanew  FH_char0  FH_char1  ...  filesize    E_file  fileinfo  class
# 0   184       256         0         1  ...   1181520  6.627552         1      0
# 1   184       184         0         1  ...      7680  5.318221         0      0
# 2   184       272         0         1  ...     57872  6.507758         1      0
# 3   184       184         0         1  ...     95616  4.575092         1      0
# 4   184       224         0         1  ...     48128  5.545531         1      0
#
# [5 rows x 64 columns]

# %%
# Dividing data into training, testing and validation
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.05, random_state=1)

# %%
# Scaling data. Default scaling is to scale the data to unit variance (or equivalent
mms = MinMaxScaler()
X_train = mms.fit_transform(X_train)
X_test = mms.transform(X_test)
X_val = mms.transform(X_val)

X_val = torch.tensor(X_val, dtype=torch.float)
X_test = torch.tensor(X_test, dtype=torch.float)
X_train = torch.tensor(X_train, dtype=torch.float)

# %% [markdown]
# ## **CNN Wing 1**

# %%
final_dims = 15
current_dims = len(df.columns)-1

# %%
pt_x_train = torch.from_numpy(np.array(X_train)).to(torch.float)
pt_y_train = torch.from_numpy(np.array(y_train)).to(torch.float)
pt_train = TensorDataset(pt_x_train, pt_y_train)
pt_train = DataLoader(pt_train, batch_size=64)

# %%
class CNN1(nn.Module):
  def __init__(self):
    super(CNN1, self).__init__()
    self.cnn = nn.Sequential(
        nn.Conv1d(1,3,kernel_size = (1,4), stride=1),
        nn.ReLU(),
        nn.BatchNorm2d(3),
        nn.Conv1d(3,3,kernel_size = (1,4), stride=1),
        nn.ReLU(),
        nn.BatchNorm2d(3),
        nn.Conv1d(3,3,kernel_size = (1,4), stride=1),
        nn.ReLU(),
        nn.BatchNorm2d(3),
        nn.Flatten(),
        nn.Linear(162, 15),
        nn.ReLU()
    )

    self.clf = nn.Sequential(
        nn.Linear(15,1),
        nn.Sigmoid()
    )

  def forward(self, x):
    features = self.cnn(x)
    return self.clf(features)

  def transform(self, x):
    return self.cnn(x)

# %%
cnn = CNN1()
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(cnn.parameters(), lr = 4e-4)

# %%
num_epochs = 100
outputs = []
losses = []
for epoch in range(num_epochs):
  for instance, y in pt_train:
    output = cnn(instance.view(-1,1,1,63))
    loss = criterion(output.view(-1,1), y.view(-1,1))
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
  losses.append(loss.item())
  print(f'Epoch:{epoch+1}, Loss:{loss.item():.4f}')
# Out:
# Epoch:1, Loss:0.4415
# Epoch:2, Loss:0.3489
# Epoch:3, Loss:0.3088
# Epoch:4, Loss:0.2880
# Epoch:5, Loss:0.2728
# Epoch:6, Loss:0.2625
# Epoch:7, Loss:0.2550
# Epoch:8, Loss:0.2487
# Epoch:9, Loss:0.2423
# Epoch:10, Loss:0.2390
# Epoch:11, Loss:0.2335
# Epoch:12, Loss:0.2338
# Epoch:13, Loss:0.2299
# Epoch:14, Loss:0.2311
# Epoch:15, Loss:0.2271
# Epoch:16, Loss:0.2247
# Epoch:17, Loss:0.2203
# Epoch:18, Loss:0.2178
# Epoch:19, Loss:0.2155
# Epoch:20, Loss:0.2151
# Epoch:21, Loss:0.2115
# Epoch:22, Loss:0.2110
# Epoch:23, Loss:0.2098
# Epoch:24, Loss:0.2077
# Epoch:25, Loss:0.2054
# Epoch:26, Loss:0.2050
# Epoch:27, Loss:0.2038
# Epoch:28, Loss:0.1995
# Epoch:29, Loss:0.2017
# Epoch:30, Loss:0.1995
# Epoch:31, Loss:0.2000
# Epoch:32, Loss:0.1979
# Epoch:33, Loss:0.1978
# Epoch:34, Loss:0.1970
# Epoch:35, Loss:0.1957
# Epoch:36, Loss:0.1944
# Epoch:37, Loss:0.1937
# Epoch:38, Loss:0.1955
# Epoch:39, Loss:0.1925
# Epoch:40, Loss:0.1924
# Epoch:41, Loss:0.1916
# Epoch:42, Loss:0.1919
# Epoch:43, Loss:0.1952
# Epoch:44, Loss:0.1954
# Epoch:45, Loss:0.1953
# Epoch:46, Loss:0.1938
# Epoch:47, Loss:0.1949
# Epoch:48, Loss:0.1959
# Epoch:49, Loss:0.1953
# Epoch:50, Loss:0.1909
# Epoch:51, Loss:0.1888
# Epoch:52, Loss:0.1867
# Epoch:53, Loss:0.1895
# Epoch:54, Loss:0.1866
# Epoch:55, Loss:0.1847
# Epoch:56, Loss:0.1803
# Epoch:57, Loss:0.1812
# Epoch:58, Loss:0.1811
# Epoch:59, Loss:0.1797
# Epoch:60, Loss:0.1814
# Epoch:61, Loss:0.1786
# Epoch:62, Loss:0.1799
# Epoch:63, Loss:0.1775
# Epoch:64, Loss:0.1791
# Epoch:65, Loss:0.1754
# Epoch:66, Loss:0.1791
# Epoch:67, Loss:0.1778
# Epoch:68, Loss:0.1782
# Epoch:69, Loss:0.1769
# Epoch:70, Loss:0.1764
# Epoch:71, Loss:0.1733
# Epoch:72, Loss:0.1766
# Epoch:73, Loss:0.1762
# Epoch:74, Loss:0.1740
# Epoch:75, Loss:0.1717
# Epoch:76, Loss:0.1743
# Epoch:77, Loss:0.1695
# Epoch:78, Loss:0.1730
# Epoch:79, Loss:0.1715
# Epoch:80, Loss:0.1742
# Epoch:81, Loss:0.1701
# Epoch:82, Loss:0.1729
# Epoch:83, Loss:0.1717
# Epoch:84, Loss:0.1739
# Epoch:85, Loss:0.1727
# Epoch:86, Loss:0.1715
# Epoch:87, Loss:0.1712
# Epoch:88, Loss:0.1712
# Epoch:89, Loss:0.1705
# Epoch:90, Loss:0.1684
# Epoch:91, Loss:0.1686
# Epoch:92, Loss:0.1659
# Epoch:93, Loss:0.1684
# Epoch:94, Loss:0.1675
# Epoch:95, Loss:0.1664
# Epoch:96, Loss:0.1661
# Epoch:97, Loss:0.1656
# Epoch:98, Loss:0.1653
# Epoch:99, Loss:0.1650
# Epoch:100, Loss:0.1639

# %%
plt.plot(losses)
plt.xlabel(f"epochs({num_epochs})")
plt.ylabel(f"loss")
_ = plt.legend(['Loss(D)'])

# %%
cnn.eval()
with torch.no_grad():
  encoded_train_X = cnn.transform(X_train.view(-1,1,1,63)).view(-1,15)
  encoded_test_X = cnn.transform(X_test.view(-1,1,1,63)).view(-1,15)

# %%
encoded_train_X.size(), encoded_test_X.size()
# Out:
# (torch.Size([3711, 15]), torch.Size([1303, 15]))

# %%
X_train = encoded_train_X.detach().numpy()
X_test = encoded_test_X.detach().numpy()

# %% [markdown]
# ## MLP Classifier on encoded data

# %%
from sklearn.neural_network import MLPClassifier

#LBFGS is the optimizer, which works relatively better when applied on 
#smaller datasets because it's a local search algorithm
clf = MLPClassifier(solver='adam', alpha=1e-5,
                    hidden_layer_sizes=(5,2), random_state=1)

clf.fit(X_train, y_train)
# Out:
# MLPClassifier(alpha=1e-05, hidden_layer_sizes=(5, 2), random_state=1)

# %%
y_pred = clf.predict(X_test)
lr_probs = clf.predict_proba(X_test)
lr_probs = lr_probs[:, 1]

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
tn=cm[0][0] #tn
fn=cm[0][1] #fn
fp=cm[1][0] #fp
tp=cm[1][1] #tp
acc= (tp+tn)/(tp+tn+fn+fp)
epsilon = 1e-7 # is used so that to avoid divide by zero error
precision = tp / (tp + fp + epsilon)
recall = tp / (tp + fn + epsilon)
sensitivity,specificity = tp/(tp+fn),tn/(tn+fp)
print("Test accuracy is:"+str(format(acc,'.4f')))
print("Precision: "+str(format(precision,'.4f'))+" Recall: "+str(format(recall,'.4f')))
# Out:
# Test accuracy is:0.9486
# Precision: 0.9640 Recall: 0.9372

# %%
scores = cross_val_score(clf, X_train, y_train, cv=5)
print('Average CV Score: ',scores.mean())
scores
# Out:
# Average CV Score:  0.970360199235996
# array([0.96366083, 0.9703504 , 0.97439353, 0.96495957, 0.97843666])

# %%
from sklearn.metrics import auc
from sklearn.metrics import accuracy_score
lr_precision, lr_recall, _ = precision_recall_curve(y_test, lr_probs)
lr_f1, lr_auc = f1_score(y_test, y_pred), auc(lr_recall, lr_precision)
no_skill = len(y_test[y_test==1]) / len(y_test)
acc = accuracy_score(y_test, y_pred)
pyplot.plot([0, 1], [no_skill, no_skill], linestyle='--', label='No Skill')
pyplot.plot(lr_recall, lr_precision, marker='.', label='Logistic')
# axis labels
pyplot.xlabel('Recall')
pyplot.ylabel('Precision')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()

print("F1:",lr_f1)
print("AUC:",lr_auc)
print("Accuracy",acc)

_ = ConfusionMatrixDisplay.from_estimator(clf, X_test, y_test, cmap="Blues")
# Out:
# F1: 0.9504071058475204
# AUC: 0.9907107676160708
# Accuracy 0.9485801995395242

# %%
torch.save(cnn.state_dict(), 'cnn1.pt')
