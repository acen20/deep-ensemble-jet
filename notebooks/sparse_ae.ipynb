# %%
import torch
from torch import nn
from torchvision import transforms
from torch.utils.data import TensorDataset, DataLoader
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve
from matplotlib import pyplot
from sklearn.metrics import f1_score
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.model_selection import cross_val_score
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.preprocessing import MinMaxScaler

# %%
from warnings import simplefilter
from sklearn.exceptions import ConvergenceWarning
simplefilter("ignore", category=ConvergenceWarning)

# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# Loading Dataset
# Dataset link: https://data.mendeley.com/datasets/xvyv59vwvz/1
# Dataset is present in the current directory containing the code file.
df=pd.read_csv('..dataset/data.csv')

# %% [markdown]
# ## Preprocessing

# %%
df.head()
# Out:
#    e_cblp  e_cp  e_cparhdr  e_maxalloc  ...  filesize    E_file  fileinfo  class
# 0     144     3          4       65535  ...   1181520  6.627552         1      0
# 1     144     3          4       65535  ...      7680  5.318221         0      0
# 2     144     3          4       65535  ...     57872  6.507758         1      0
# 3     144     3          4       65535  ...     95616  4.575092         1      0
# 4     144     3          4       65535  ...     48128  5.545531         1      0
#
# [5 rows x 70 columns]

# %%
# Replacing Null values with 0. ML classifer cannot learn on Null values
df.fillna(0, inplace=True)

# %%
# Peak on dataset
df.head()
# Out:
#    e_cblp  e_cp  e_cparhdr  e_maxalloc  ...  filesize    E_file  fileinfo  class
# 0     144     3          4       65535  ...   1181520  6.627552         1      0
# 1     144     3          4       65535  ...      7680  5.318221         0      0
# 2     144     3          4       65535  ...     57872  6.507758         1      0
# 3     144     3          4       65535  ...     95616  4.575092         1      0
# 4     144     3          4       65535  ...     48128  5.545531         1      0
#
# [5 rows x 70 columns]

# %%
# Droping these columns due to their insignificance
df=df.drop(['NumberOfSections','CreationYear','e_cblp','e_cp','e_cparhdr','e_maxalloc'], axis=1)

# %%
df.shape
# Out:
# (5210, 64)

# %%
# Peak on the dataset
df.head()
# Out:
#    e_sp  e_lfanew  FH_char0  FH_char1  ...  filesize    E_file  fileinfo  class
# 0   184       256         0         1  ...   1181520  6.627552         1      0
# 1   184       184         0         1  ...      7680  5.318221         0      0
# 2   184       272         0         1  ...     57872  6.507758         1      0
# 3   184       184         0         1  ...     95616  4.575092         1      0
# 4   184       224         0         1  ...     48128  5.545531         1      0
#
# [5 rows x 64 columns]

# %%
yes,no = df['class'].value_counts()

# %%
print(yes,no)
# Out:
# 2722 2488

# %%
#No class has less instances

# %%
# Encodings Labels so that they are compatible with machine leanring classifiers
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in df:
    if df[i].dtype=='object':
        df[i] = le.fit_transform(df[i])
    else:
        continue
X = df.drop(['class'],axis=1)
y = df['class']

# %%
# Now check the features for the feature column "Packer_type". They are converted fr
df.head()
# Out:
#    e_sp  e_lfanew  FH_char0  FH_char1  ...  filesize    E_file  fileinfo  class
# 0   184       256         0         1  ...   1181520  6.627552         1      0
# 1   184       184         0         1  ...      7680  5.318221         0      0
# 2   184       272         0         1  ...     57872  6.507758         1      0
# 3   184       184         0         1  ...     95616  4.575092         1      0
# 4   184       224         0         1  ...     48128  5.545531         1      0
#
# [5 rows x 64 columns]

# %%
# Dividing data into training, testing and validation
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.05, random_state=1)

# %%
# Scaling data. Default scaling is to scale the data to unit variance (or equivalent
mms = MinMaxScaler()
X_train = mms.fit_transform(X_train)
X_test = mms.transform(X_test)
X_val = mms.transform(X_val)

X_val = torch.tensor(X_val, dtype=torch.float)
X_test = torch.tensor(X_test, dtype=torch.float)
X_train = torch.tensor(X_train, dtype=torch.float)

# %% [markdown]
# ## Autoencoder reducing dims to 15

# %%
features = 15
current_dims = len(df.columns)-1

# %%
pt_x_train = torch.from_numpy(np.array(X_train))
pt_y_train = torch.from_numpy(np.array(y_train))
pt_train = TensorDataset(pt_x_train, pt_y_train)
pt_train = DataLoader(pt_train, batch_size=64)

# %%
class Encoder(nn.Module):
  def __init__(self):
    super().__init__()
    self.encoder = nn.Sequential(
        nn.Linear(current_dims, current_dims*2),
        nn.BatchNorm1d(current_dims*2),
        nn.LeakyReLU(),
        nn.Dropout(0.1),
        nn.Linear(current_dims*2, current_dims*2),
        nn.BatchNorm1d(current_dims*2),
        nn.LeakyReLU(),
        nn.Dropout(0.1),
        nn.Linear(current_dims*2, current_dims*2),
        nn.BatchNorm1d(current_dims*2),
        nn.LeakyReLU(),
        nn.Dropout(0.1),
        nn.Linear(current_dims*2, features),
        nn.BatchNorm1d(features),
        nn.LeakyReLU(),
    )

  def forward(self, x):
    encoded = self.encoder(x)
    return encoded

# %%
class Decoder(nn.Module):
  def __init__(self):
    super().__init__()
    self.decoder = nn.Sequential(
        nn.Linear(features, current_dims*2),
        nn.BatchNorm1d(current_dims*2),
        nn.LeakyReLU(),
        nn.Dropout(0.1),
        nn.Linear(current_dims*2, current_dims*2),
        nn.BatchNorm1d(current_dims*2),
        nn.LeakyReLU(),
        nn.Dropout(0.1),
        nn.Linear(current_dims*2, current_dims*2),
        nn.BatchNorm1d(current_dims*2),
        nn.LeakyReLU(),
        nn.Dropout(0.1),
        nn.Linear(current_dims*2, current_dims),
        nn.Sigmoid()
    )

  def forward(self, x):
    decoded = self.decoder(x)
    return decoded

# %%
encoder = Encoder()
decoder = Decoder()
parameters = list(encoder.parameters())+ list(decoder.parameters())
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(parameters, lr = 1e-1, weight_decay=1e-6)

# %%
num_epochs = 200
outputs = []
losses = []
for epoch in range(num_epochs):
  for instance,_ in pt_train:
    encoded = encoder(instance)
    reconstructed = decoder(encoded)
    loss = criterion(reconstructed, instance)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
  losses.append(loss.item())
  print(f'Epoch:{epoch+1}, Loss:{loss.item():.4f}')
# Out:
# Epoch:1, Loss:0.1722
# Epoch:2, Loss:0.1290
# Epoch:3, Loss:0.1020
# Epoch:4, Loss:0.0819
# Epoch:5, Loss:0.0696
# Epoch:6, Loss:0.0600
# Epoch:7, Loss:0.0526
# Epoch:8, Loss:0.0482
# Epoch:9, Loss:0.0443
# Epoch:10, Loss:0.0407
# Epoch:11, Loss:0.0383
# Epoch:12, Loss:0.0365
# Epoch:13, Loss:0.0345
# Epoch:14, Loss:0.0327
# Epoch:15, Loss:0.0310
# Epoch:16, Loss:0.0293
# Epoch:17, Loss:0.0290
# Epoch:18, Loss:0.0280
# Epoch:19, Loss:0.0269
# Epoch:20, Loss:0.0256
# Epoch:21, Loss:0.0254
# Epoch:22, Loss:0.0244
# Epoch:23, Loss:0.0248
# Epoch:24, Loss:0.0238
# Epoch:25, Loss:0.0235
# Epoch:26, Loss:0.0230
# Epoch:27, Loss:0.0228
# Epoch:28, Loss:0.0224
# Epoch:29, Loss:0.0218
# Epoch:30, Loss:0.0217
# Epoch:31, Loss:0.0211
# Epoch:32, Loss:0.0209
# Epoch:33, Loss:0.0204
# Epoch:34, Loss:0.0207
# Epoch:35, Loss:0.0201
# Epoch:36, Loss:0.0200
# Epoch:37, Loss:0.0195
# Epoch:38, Loss:0.0194
# Epoch:39, Loss:0.0195
# Epoch:40, Loss:0.0198
# Epoch:41, Loss:0.0198
# Epoch:42, Loss:0.0189
# Epoch:43, Loss:0.0186
# Epoch:44, Loss:0.0183
# Epoch:45, Loss:0.0183
# Epoch:46, Loss:0.0185
# Epoch:47, Loss:0.0189
# Epoch:48, Loss:0.0187
# Epoch:49, Loss:0.0180
# Epoch:50, Loss:0.0173
# Epoch:51, Loss:0.0178
# Epoch:52, Loss:0.0174
# Epoch:53, Loss:0.0174
# Epoch:54, Loss:0.0174
# Epoch:55, Loss:0.0178
# Epoch:56, Loss:0.0171
# Epoch:57, Loss:0.0169
# Epoch:58, Loss:0.0169
# Epoch:59, Loss:0.0167
# Epoch:60, Loss:0.0166
# Epoch:61, Loss:0.0173
# Epoch:62, Loss:0.0160
# Epoch:63, Loss:0.0165
# Epoch:64, Loss:0.0166
# Epoch:65, Loss:0.0160
# Epoch:66, Loss:0.0160
# Epoch:67, Loss:0.0166
# Epoch:68, Loss:0.0164
# Epoch:69, Loss:0.0159
# Epoch:70, Loss:0.0171
# Epoch:71, Loss:0.0160
# Epoch:72, Loss:0.0164
# Epoch:73, Loss:0.0160
# Epoch:74, Loss:0.0150
# Epoch:75, Loss:0.0153
# Epoch:76, Loss:0.0153
# Epoch:77, Loss:0.0144
# Epoch:78, Loss:0.0153
# Epoch:79, Loss:0.0151
# Epoch:80, Loss:0.0151
# Epoch:81, Loss:0.0154
# Epoch:82, Loss:0.0143
# Epoch:83, Loss:0.0149
# Epoch:84, Loss:0.0149
# Epoch:85, Loss:0.0147
# Epoch:86, Loss:0.0149
# Epoch:87, Loss:0.0143
# Epoch:88, Loss:0.0150
# Epoch:89, Loss:0.0146
# Epoch:90, Loss:0.0143
# Epoch:91, Loss:0.0142
# Epoch:92, Loss:0.0145
# Epoch:93, Loss:0.0142
# Epoch:94, Loss:0.0149
# Epoch:95, Loss:0.0141
# Epoch:96, Loss:0.0138
# Epoch:97, Loss:0.0145
# Epoch:98, Loss:0.0139
# Epoch:99, Loss:0.0134
# Epoch:100, Loss:0.0143
# Epoch:101, Loss:0.0143
# Epoch:102, Loss:0.0143
# Epoch:103, Loss:0.0136
# Epoch:104, Loss:0.0135
# Epoch:105, Loss:0.0131
# Epoch:106, Loss:0.0140
# Epoch:107, Loss:0.0139
# Epoch:108, Loss:0.0133
# Epoch:109, Loss:0.0129
# Epoch:110, Loss:0.0132
# Epoch:111, Loss:0.0138
# Epoch:112, Loss:0.0135
# Epoch:113, Loss:0.0133
# Epoch:114, Loss:0.0135
# Epoch:115, Loss:0.0134
# Epoch:116, Loss:0.0132
# Epoch:117, Loss:0.0128
# Epoch:118, Loss:0.0135
# Epoch:119, Loss:0.0131
# Epoch:120, Loss:0.0130
# Epoch:121, Loss:0.0134
# Epoch:122, Loss:0.0130
# Epoch:123, Loss:0.0128
# Epoch:124, Loss:0.0128
# Epoch:125, Loss:0.0131
# Epoch:126, Loss:0.0129
# Epoch:127, Loss:0.0130
# Epoch:128, Loss:0.0129
# Epoch:129, Loss:0.0136
# Epoch:130, Loss:0.0129
# Epoch:131, Loss:0.0128
# Epoch:132, Loss:0.0127
# Epoch:133, Loss:0.0127
# Epoch:134, Loss:0.0122
# Epoch:135, Loss:0.0122
# Epoch:136, Loss:0.0124
# Epoch:137, Loss:0.0125
# Epoch:138, Loss:0.0121
# Epoch:139, Loss:0.0123
# Epoch:140, Loss:0.0123
# Epoch:141, Loss:0.0125
# Epoch:142, Loss:0.0120
# Epoch:143, Loss:0.0127
# Epoch:144, Loss:0.0120
# Epoch:145, Loss:0.0113
# Epoch:146, Loss:0.0116
# Epoch:147, Loss:0.0125
# Epoch:148, Loss:0.0121
# Epoch:149, Loss:0.0119
# Epoch:150, Loss:0.0119
# Epoch:151, Loss:0.0126
# Epoch:152, Loss:0.0118
# Epoch:153, Loss:0.0118
# Epoch:154, Loss:0.0124
# Epoch:155, Loss:0.0118
# Epoch:156, Loss:0.0117
# Epoch:157, Loss:0.0117
# Epoch:158, Loss:0.0123
# Epoch:159, Loss:0.0118
# Epoch:160, Loss:0.0124
# Epoch:161, Loss:0.0114
# Epoch:162, Loss:0.0118
# Epoch:163, Loss:0.0119
# Epoch:164, Loss:0.0117
# Epoch:165, Loss:0.0120
# Epoch:166, Loss:0.0116
# Epoch:167, Loss:0.0117
# Epoch:168, Loss:0.0116
# Epoch:169, Loss:0.0113
# Epoch:170, Loss:0.0116
# Epoch:171, Loss:0.0117
# Epoch:172, Loss:0.0112
# Epoch:173, Loss:0.0114
# Epoch:174, Loss:0.0115
# Epoch:175, Loss:0.0116
# Epoch:176, Loss:0.0114
# Epoch:177, Loss:0.0112
# Epoch:178, Loss:0.0117
# Epoch:179, Loss:0.0119
# Epoch:180, Loss:0.0118
# Epoch:181, Loss:0.0118
# Epoch:182, Loss:0.0113
# Epoch:183, Loss:0.0110
# Epoch:184, Loss:0.0113
# Epoch:185, Loss:0.0111
# Epoch:186, Loss:0.0112
# Epoch:187, Loss:0.0112
# Epoch:188, Loss:0.0109
# Epoch:189, Loss:0.0108
# Epoch:190, Loss:0.0110
# Epoch:191, Loss:0.0119
# Epoch:192, Loss:0.0116
# Epoch:193, Loss:0.0105
# Epoch:194, Loss:0.0107
# Epoch:195, Loss:0.0115
# Epoch:196, Loss:0.0109
# Epoch:197, Loss:0.0110
# Epoch:198, Loss:0.0107
# Epoch:199, Loss:0.0108
# Epoch:200, Loss:0.0107

# %%
plt.plot(losses)
plt.xlabel(f"epochs({num_epochs})")
plt.ylabel(f"loss")
_ = plt.legend(['Loss(D)'])

# %%
with torch.no_grad():
  encoded_train_X = encoder.forward(X_train)
  encoded_test_X = encoder.forward(X_test)

# %%
encoded_train_X.size(), encoded_test_X.size()
# Out:
# (torch.Size([3711, 15]), torch.Size([1303, 15]))

# %%
X_train = encoded_train_X.detach().numpy()
X_test = encoded_test_X.detach().numpy()

# %% [markdown]
# ## MLP Classifier on encoded data

# %%
from sklearn.neural_network import MLPClassifier

#LBFGS is the optimizer, which works relatively better when applied on 
#smaller datasets because it's a local search algorithm
clf = MLPClassifier(solver='adam', alpha=1e-5,
                    hidden_layer_sizes=(5,2), random_state=1)

clf.fit(X_train, y_train)
# Out:
# MLPClassifier(alpha=1e-05, hidden_layer_sizes=(5, 2), random_state=1)

# %%
y_pred = clf.predict(X_test)
lr_probs = clf.predict_proba(X_test)
lr_probs = lr_probs[:, 1]

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
tn=cm[0][0] #tn
fn=cm[0][1] #fn
fp=cm[1][0] #fp
tp=cm[1][1] #tp
acc= (tp+tn)/(tp+tn+fn+fp)
epsilon = 1e-7 # is used so that to avoid divide by zero error
precision = tp / (tp + fp + epsilon)
recall = tp / (tp + fn + epsilon)
sensitivity,specificity = tp/(tp+fn),tn/(tn+fp)
print("Test accuracy is:"+str(format(acc,'.4f')))
print("Precision: "+str(format(precision,'.4f'))+" Recall: "+str(format(recall,'.4f')))
# Out:
# Test accuracy is:0.9202
# Precision: 0.9535 Recall: 0.8969

# %%
scores = cross_val_score(clf, X_train, y_train, cv=5)
print('Average CV Score: ',scores.mean())
scores
# Out:
# Average CV Score:  0.9250880636162131
# array([0.92328398, 0.91913747, 0.92587601, 0.91913747, 0.93800539])

# %%
from sklearn.metrics import auc
from sklearn.metrics import accuracy_score
lr_precision, lr_recall, _ = precision_recall_curve(y_test, lr_probs)
lr_f1, lr_auc = f1_score(y_test, y_pred), auc(lr_recall, lr_precision)
no_skill = len(y_test[y_test==1]) / len(y_test)
acc = accuracy_score(y_test, y_pred)
pyplot.plot([0, 1], [no_skill, no_skill], linestyle='--', label='No Skill')
pyplot.plot(lr_recall, lr_precision, marker='.', label='Logistic')
# axis labels
pyplot.xlabel('Recall')
pyplot.ylabel('Precision')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()

print("F1:",lr_f1)
print("AUC:",lr_auc)
print("Accuracy",acc)

ConfusionMatrixDisplay.from_estimator(clf, X_test, y_test, cmap="Blues")
# Out:
# F1: 0.9243085880640466
# AUC: 0.9658433537465088
# Accuracy 0.9201841903300076

# %%
torch.save(encoder.state_dict(), 'sparse_encoder.pt')
